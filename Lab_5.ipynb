# %% [markdown]
# <a href="https://colab.research.google.com/github/ankur36900/ALGO-LAB-/blob/main/Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt

def selection_sort(numbers):
    n = len(numbers)
    for i in range(n):
        min_index = i
        for j in range(i + 1, n):
            if numbers[j] < numbers[min_index]:
                min_index = j
        numbers[i], numbers[min_index] = numbers[min_index], numbers[i]
    return numbers

n = int(input("Enter number of elements: "))

numbers = []
for i in range(n):
    element = int(input(f"Enter element {i+1}: "))
    numbers.append(element)

print("\nOriginal List:", numbers)

start_time = time.time()
sorted_list = selection_sort(numbers.copy())
end_time = time.time()

print("Sorted List:", sorted_list)
print("Running Time (seconds):", end_time - start_time)

sizes = []
times = []

for size in range(100, 1100, 100):
    test_data = random.sample(range(10000), size)
    start = time.time()
    selection_sort(test_data)
    end = time.time()
    sizes.append(size)
    times.append(end - start)

plt.plot(sizes, times, marker='o')
plt.title("Selection Sort Time Complexity")
plt.xlabel("Input Size (n)")
plt.ylabel("Running Time (seconds)")
plt.grid(True)
plt.show()
# Out:
# Enter number of elements: 3
# Enter element 1: 3
# Enter element 2: 2
# Enter element 3: 1
#
# Original List: [3, 2, 1]
# Sorted List: [1, 2, 3]
# Running Time (seconds): 8.797645568847656e-05

# %% [markdown]
# ## Implement Quick Sort
#
# ### Subtask:
# Write the Python function `quick_sort(arr)` that implements the quick sort algorithm as described in the text cell. The function should sort the input list `arr`.

# %% [markdown]
# ####
#  In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

n = int(input("Enter number of elements: "))

arr = []
for i in range(n):
    element = int(input(f"Enter element {i+1}: "))
    arr.append(element)

print("\nOriginal List:", arr)

start_time = time.time()
sorted_arr = quick_sort(arr)
end_time = time.time()

print("Sorted List:", sorted_arr)
print("Running Time (seconds):", end_time - start_time)

sizes = []
times = []

for size in range(100, 2100, 200):
    test_data = random.sample(range(10000), size)
    start = time.time()
    quick_sort(test_data)
    end = time.time()
    sizes.append(size)
    times.append(end - start)

plt.plot(sizes, times, marker='o')
plt.title("Quick Sort Time Complexity")
plt.xlabel("Input Size (n)")
plt.ylabel("Running Time (seconds)")
plt.grid(True)
plt.show()
# Out:
# Enter number of elements: 3
# Enter element 1: 3
# Enter element 2: 2
# Enter element 3: 1
#
# Original List: [3, 2, 1]
# Sorted List: [1, 2, 3]
# Running Time (seconds): 0.00010609626770019531

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[0]
    left = []
    right = []
    for i in range(1, len(arr)):
        if arr[i] <= pivot:
            left.append(arr[i])
        else:
            right.append(arr[i])
    return quick_sort(left) + [pivot] + quick_sort(right)

n = int(input("Enter number of elements: "))

arr = []
for i in range(n):
    element = int(input(f"Enter element {i+1}: "))
    arr.append(element)

print("\nOriginal List:", arr)

start_time = time.time()
sorted_arr = quick_sort(arr)
end_time = time.time()

print("Sorted List:", sorted_arr)
print("Running Time (seconds):", end_time - start_time)

sizes = []
times = []

for size in range(100, 2100, 200):
    test_data = random.sample(range(10000), size)
    start = time.time()
    quick_sort(test_data)
    end = time.time()
    sizes.append(size)
    times.append(end - start)

plt.plot(sizes, times, marker='o')
plt.title("Quick Sort Time Complexity")
plt.xlabel("Input Size (n)")
plt.ylabel("Running Time (seconds)")
plt.grid(True)
plt.show()
# Out:
# Enter number of elements: 4
# Enter element 1: 534
# Enter element 2: 643
# Enter element 3: 765
# Enter element 4: 435
#
# Original List: [534, 643, 765, 435]
# Sorted List: [435, 534, 643, 765]
# Running Time (seconds): 0.0001361370086669922

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Experiment variables
n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
n_max = n_list[len(n_list) -1]

# %%
import datetime
import random

# Creating a random value (uniform)
ms = datetime.datetime.now().microsecond / 1000
random.seed(ms)

numbers = []
for i in range(n_max):
    numbers.append(int(random.random() * 1000))

# %%
import timeit
import copy # Import the copy module

a_time = []
b_time = []
c_time = []

for l in n_list:
    a = copy.deepcopy(numbers[0:l])
    b = copy.deepcopy(numbers[0:l])
    c = copy.deepcopy(numbers[0:l])

    start_time = timeit.default_timer()
    # Assuming quick_sort is defined elsewhere and takes a list
    quick_sort(a)
    a_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    # Assuming merge_sort is defined elsewhere and takes a list
    merge_sort(b)
    b_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    # Assuming selection_sort is defined elsewhere and sorts in-place
    # Note: The original code had 'selection.sort()', which is incorrect if selection is a list.
    # It should be selection_sort(c) if using the defined function, or c.sort() for Python's built-in sort.
    # Based on previous cells, selection_sort(c) seems more appropriate.
    selection_sort(c)
    c_time.append((timeit.default_timer() - start_time) * 1000)

# %%
# Plotting results
plt.figure(figsize=(10, 5))
plt.plot(a_time, linewidth = 1, marker="o")
plt.plot(b_time, linewidth = 1, marker="o")
plt.plot(c_time, linewidth = 1, marker="o")
plt.xticks(np.arange(len(n_list)), n_list)
plt.title("Compare Sorting Algorithms", fontsize = 14)
plt.ylabel('Time (ms)')
plt.xlabel('n')
plt.legend(("Quicksort", "Mergesort", "Selection sort"), loc = "best")
plt.show()

# %% [markdown]
# # Task
# Implement selection sort, demonstrate its functionality with a sample list, then measure its execution time for various input sizes and plot the results. Ensure to import `time`, `random`, `matplotlib.pyplot` as `plt`, and `numpy` as `np` for timing, data generation, and plotting, respectively.

# %% [markdown]
# ## Import Libraries
#
# ### Subtask:
# Import `time`, `random`, `matplotlib.pyplot` as `plt`, and `numpy` as `np` to support timing measurements, data generation, and plotting within the notebook. This will also resolve the `NameError` for `plt` in later cells.

# %% [markdown]
# **Reasoning**:
# The subtask requires importing specific libraries to support the functionality in the notebook, including resolving a `NameError` for `plt`. Importing them now ensures they are available for subsequent code cells.

# %%
import time
import random
import matplotlib.pyplot as plt
import numpy as np

print("Libraries imported successfully: time, random, matplotlib.pyplot as plt, numpy as np")
# Out:
# Libraries imported successfully: time, random, matplotlib.pyplot as plt, numpy as np

# %% [markdown]
# ## Implement Selection Sort
#
# ### Subtask:
# Write the Python function `selection_sort(arr)` that implements the selection sort algorithm as described in the text cell. The function will sort the input list `arr` in-place.

# %% [markdown]
# **Reasoning**:
# The subtask requires implementing the `selection_sort` function. I will create a Python code block that defines this function as specified in the instructions, including the outer loop, inner loop to find the minimum element, and the swap operation.

# %%
def selection_sort(arr):
    """
    Sorts a list using the selection sort algorithm in-place.
    """
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        # Swap the found minimum element with the first element of the unsorted part
        if min_idx != i:
            arr[i], arr[min_idx] = arr[min_idx], arr[i]
    print("Selection sort function defined.")

# Example usage to demonstrate functionality (will be removed in final version)
# sample_list = [64, 25, 12, 22, 11]
# print("Original list:", sample_list)
# selection_sort(sample_list)
# print("Sorted list:", sample_list)

# %% [markdown]
# ### Demonstrate Selection Sort
#
# To ensure the `selection_sort` function works as expected, we will test it with a sample list and print the original and sorted versions of the list.

# %% [markdown]
# ### Demonstrate Selection Sort
#
# To ensure the `selection_sort` function works as expected, we will test it with a sample list and print the original and sorted versions of the list.

# %% [markdown]
# **Reasoning**:
# Following the markdown explanation, I will now write the Python code to demonstrate the `selection_sort` function by creating a sample list, applying the sort, and printing the list before and after sorting.

# %%
sample_list = [64, 25, 12, 22, 11]
print("Original list:", sample_list)
selection_sort(sample_list)
print("Sorted list:", sample_list)
# Out:
# Original list: [64, 25, 12, 22, 11]
# Selection sort function defined.
# Sorted list: [11, 12, 22, 25, 64]

# %% [markdown]
# ## Measure Execution Time of Selection Sort
#
# Now, we will measure the execution time of the `selection_sort` algorithm for different input sizes (`n`). We will use a predefined list of `n` values and generate random data for each `n` to ensure fair comparison.

# %% [markdown]
# ## Measure Execution Time of Selection Sort
#
# Now, we will measure the execution time of the `selection_sort` algorithm for different input sizes (`n`). We will use a predefined list of `n` values and generate random data for each `n` to ensure fair comparison.

# %% [markdown]
# **Reasoning**:
# To measure the execution time of selection sort, I need a list of input sizes (`n_list_selection_sort`) appropriate for its quadratic complexity and a corresponding list of random numbers up to the maximum `n`.

# %%
n_list_selection_sort = [100, 200, 500, 1000, 2000, 5000]
n_max_selection_sort = n_list_selection_sort[-1]

# Generate random numbers for the maximum size
random.seed(42) # Using a fixed seed for reproducibility
selection_sort_numbers = [random.randint(0, 10000) for _ in range(n_max_selection_sort)]

print(f"Selection sort specific n_list: {n_list_selection_sort}")
print(f"Generated {len(selection_sort_numbers)} random numbers for selection sort testing.")
# Out:
# Selection sort specific n_list: [100, 200, 500, 1000, 2000, 5000]
# Generated 5000 random numbers for selection sort testing.

# %% [markdown]
# **Reasoning**:
# Now that the input sizes and random data are prepared, I will measure the execution time of the `selection_sort` function for each specified input size and store these times in a list.

# %%
selection_sort_times = []

for n in n_list_selection_sort:
    # Take a sublist of size n from the pre-generated random numbers
    data_to_sort = selection_sort_numbers[:n]

    # Make a copy to ensure the original list is not modified for subsequent runs if any
    temp_data = list(data_to_sort)

    start_time = time.time() # Record start time
    selection_sort(temp_data) # Perform selection sort
    end_time = time.time() # Record end time

    execution_time_ms = (end_time - start_time) * 1000 # Convert to milliseconds
    selection_sort_times.append(execution_time_ms)
    print(f"Selection Sort for n={n}: {execution_time_ms:.4f} ms")

print("\nExecution times for Selection Sort (ms):", selection_sort_times)
# Out:
# Selection sort function defined.
# Selection Sort for n=100: 0.7045 ms
# Selection sort function defined.
# Selection Sort for n=200: 1.2996 ms
# Selection sort function defined.
# Selection Sort for n=500: 12.7296 ms
# Selection sort function defined.
# Selection Sort for n=1000: 44.5228 ms
# Selection sort function defined.
# Selection Sort for n=2000: 195.4458 ms
# Selection sort function defined.
# Selection Sort for n=5000: 634.5983 ms
#
# Execution times for Selection Sort (ms): [0.7045269012451172, 1.2996196746826172, 12.729644775390625, 44.522762298583984, 195.44577598571777, 634.5982551574707]

# %% [markdown]
# **Reasoning**:
# Now that the execution times for selection sort have been measured and stored, the next step is to visualize these results by plotting the execution time against the input size, as requested by the main task.

# %%
plt.figure(figsize=(10, 6))
plt.plot(n_list_selection_sort, selection_sort_times, marker='o', linestyle='-', color='b')
plt.title('Selection Sort Execution Time vs. Input Size')
plt.xlabel('Input Size (n)')
plt.ylabel('Time (ms)')
plt.grid(True)
plt.xscale('log') # Use log scale for better visualization of larger differences if n values are spread out
plt.yscale('log') # Use log scale for time as well
plt.xticks(n_list_selection_sort, labels=n_list_selection_sort)
plt.ticklabel_format(style='plain', axis='x')
plt.show()

print("Plotting Selection Sort execution time vs. input size completed.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in ticklabel_format(self, axis, style, scilimits, useOffset, useLocale, useMathText)
#    3380                 if is_sci_style is not None:
# -> 3381                     axis.major.formatter.set_scientific(is_sci_style)
#    3382                 if scilimits is not None:
#
# AttributeError: 'FuncFormatter' object has no attribute 'set_scientific'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2357002345.py in <cell line: 0>()
#       8 plt.yscale('log') # Use log scale for time as well
#       9 plt.xticks(n_list_selection_sort, labels=n_list_selection_sort)
# ---> 10 plt.ticklabel_format(style='plain', axis='x')
#      11 plt.show()
# ...

# %% [markdown]
# **Reasoning**:
# The `AttributeError: This method only works with the ScalarFormatter` occurs because `plt.ticklabel_format` is incompatible with a logarithmic x-axis (`plt.xscale('log')`). Removing the `plt.ticklabel_format` line will allow matplotlib's default log formatting to handle the tick labels correctly while still using `plt.xticks` to specify the desired tick locations.

# %%
plt.figure(figsize=(10, 6))
plt.plot(n_list_selection_sort, selection_sort_times, marker='o', linestyle='-', color='b')
plt.title('Selection Sort Execution Time vs. Input Size')
plt.xlabel('Input Size (n)')
plt.ylabel('Time (ms)')
plt.grid(True)
plt.xscale('log') # Use log scale for better visualization of larger differences if n values are spread out
plt.yscale('log') # Use log scale for time as well
plt.xticks(n_list_selection_sort, labels=n_list_selection_sort)
plt.show()

print("Plotting Selection Sort execution time vs. input size completed.")
# Out:
# Plotting Selection Sort execution time vs. input size completed.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the completion of the task, confirming that selection sort has been implemented, demonstrated, timed, and plotted, and that all necessary libraries are imported.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The task asked to implement selection sort, demonstrate its functionality, measure its execution time for various input sizes, and plot the results, ensuring specific libraries are imported. All aspects of this task have been successfully completed.
#
# ### Data Analysis Key Findings
# *   All required libraries, including `time`, `random`, `matplotlib.pyplot` (as `plt`), and `numpy` (as `np`), were successfully imported.
# *   The `selection_sort` function was correctly implemented, sorting an in-place list.
# *   The `selection_sort` function was successfully demonstrated with a sample list `[64, 25, 12, 22, 11]`, which it correctly sorted to `[11, 12, 22, 25, 64]`.
# *   Execution times for the selection sort algorithm were measured for various input sizes, showing a clear increase with `n`:
#     *   For `n=100`, the time was 0.7045 ms.
#     *   For `n=500`, the time was 12.7296 ms.
#     *   For `n=5000`, the time was 634.5983 ms.
# *   The plot of "Selection Sort Execution Time vs. Input Size" was successfully generated using a log-log scale, visually representing the quadratic growth characteristic of the algorithm.
#
# ### Insights or Next Steps
# *   The observed execution times confirm that selection sort's performance degrades quadratically with increasing input size, consistent with its O(n\^2) time complexity.
# *   To further analyze performance, compare selection sort's execution times against other sorting algorithms (e.g., merge sort, quick sort) for the same input sizes to highlight efficiency differences.

# %% [markdown]
# # Task
# Implement the `merge_sort(arr)` function that sorts the input list `arr` using the merge sort algorithm, including both the recursive division and the merging steps.

# %% [markdown]
# ## Implement Merge Sort
#
# ### Subtask:
# Write the Python function `merge_sort(arr)` that implements the merge sort algorithm, including the recursive division and the merging step. The function should sort the input list `arr`.

# %% [markdown]
# **Reasoning**:
# The subtask requires implementing the `merge_sort` function. I will create a Python code block that defines this function as specified in the instructions, including the recursive division and the merging step.

# %%
def merge_sort(arr):
    """
    Sorts a list using the merge sort algorithm in-place.
    """
    if len(arr) > 1:
        mid = len(arr) // 2  # Find the middle of the array
        left_half = arr[:mid]  # Divide the array elements into two halves
        right_half = arr[mid:]

        merge_sort(left_half)  # Sort the first half
        merge_sort(right_half)  # Sort the second half

        i = j = k = 0

        # Copy data to temp arrays left_half[] and right_half[]
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1

        # Checking if any element was left
        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1
    return arr # Although sorting in-place, returning for clarity.

print("Merge sort function defined.")
# Out:
# Merge sort function defined.

# %% [markdown]
# ### Demonstrate Merge Sort
#
# To ensure the `merge_sort` function works as expected, we will test it with a sample list and print the original and sorted versions of the list.

# %% [markdown]
# **Reasoning**:
# Following the markdown explanation, I will now write the Python code to demonstrate the `merge_sort` function by creating a sample list, applying the sort, and printing the list before and after sorting.

# %%
sample_list_merge = [64, 25, 12, 22, 11, 78, 33, 90]
print("Original list for Merge Sort:", sample_list_merge)
merge_sort(sample_list_merge)
print("Sorted list by Merge Sort:", sample_list_merge)
# Out:
# Original list for Merge Sort: [64, 25, 12, 22, 11, 78, 33, 90]
# Sorted list by Merge Sort: [11, 12, 22, 25, 33, 64, 78, 90]

# %% [markdown]
# ## Measure Execution Time of Merge Sort
#
# Now, we will measure the execution time of the `merge_sort` algorithm for different input sizes (`n`). We will use a predefined list of `n` values and generate random data for each `n` to ensure fair comparison.

# %% [markdown]
# **Reasoning**:
# To measure the execution time of merge sort, I need a list of input sizes (`n_list_merge_sort`) appropriate for its typical complexity (better than selection sort, so larger `n` values) and a corresponding list of random numbers up to the maximum `n`.

# %%
n_list_merge_sort = [1000, 5000, 10000, 50000, 100000, 200000, 500000, 1000000]
n_max_merge_sort = n_list_merge_sort[-1]

# Generate random numbers for the maximum size
random.seed(42) # Using a fixed seed for reproducibility
merge_sort_numbers = [random.randint(0, 10000) for _ in range(n_max_merge_sort)]

print(f"Merge sort specific n_list: {n_list_merge_sort}")
print(f"Generated {len(merge_sort_numbers)} random numbers for merge sort testing.")
# Out:
# Merge sort specific n_list: [1000, 5000, 10000, 50000, 100000, 200000, 500000, 1000000]
# Generated 1000000 random numbers for merge sort testing.

# %% [markdown]
# **Reasoning**:
# Now that the input sizes and random data are prepared, I will measure the execution time of the `merge_sort` function for each specified input size and store these times in a list.

# %%
merge_sort_times = []

for n in n_list_merge_sort:
    # Take a sublist of size n from the pre-generated random numbers
    data_to_sort_merge = merge_sort_numbers[:n]

    # Make a copy to ensure the original list is not modified for subsequent runs if any
    temp_data_merge = list(data_to_sort_merge)

    start_time = time.time() # Record start time
    merge_sort(temp_data_merge) # Perform merge sort
    end_time = time.time() # Record end time

    execution_time_ms = (end_time - start_time) * 1000 # Convert to milliseconds
    merge_sort_times.append(execution_time_ms)
    print(f"Merge Sort for n={n}: {execution_time_ms:.4f} ms")

print("\nExecution times for Merge Sort (ms):", merge_sort_times)
# Out:
# Merge Sort for n=1000: 5.3937 ms
# Merge Sort for n=5000: 40.7720 ms
# Merge Sort for n=10000: 83.3073 ms
# Merge Sort for n=50000: 305.2669 ms
# Merge Sort for n=100000: 495.3711 ms
# Merge Sort for n=200000: 745.3480 ms
# Merge Sort for n=500000: 2116.5891 ms
# Merge Sort for n=1000000: 4569.1099 ms
#
# Execution times for Merge Sort (ms): [5.393743515014648, 40.7719612121582, 83.30726623535156, 305.2668571472168, 495.37110328674316, 745.3479766845703, 2116.589069366455, 4569.109916687012]

# %% [markdown]
# **Reasoning**:
# Now that the execution times for merge sort have been measured and stored, the next step is to visualize these results by plotting the execution time against the input size, as requested by the main task. This will help in understanding the performance characteristics of merge sort.

# %%
plt.figure(figsize=(10, 6))
plt.plot(n_list_merge_sort, merge_sort_times, marker='o', linestyle='-', color='g')
plt.title('Merge Sort Execution Time vs. Input Size')
plt.xlabel('Input Size (n)')
plt.ylabel('Time (ms)')
plt.grid(True)
plt.xscale('log') # Use log scale for better visualization of larger differences
plt.yscale('log') # Use log scale for time as well
plt.xticks(n_list_merge_sort, labels=n_list_merge_sort)
plt.show()

print("Plotting Merge Sort execution time vs. input size completed.")
# Out:
# Plotting Merge Sort execution time vs. input size completed.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the completion of the task, confirming that merge sort has been implemented, demonstrated, timed, and plotted.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The `merge_sort` algorithm has been successfully implemented, demonstrated, timed, and plotted.
#
# ### Data Analysis Key Findings
# *   **Merge Sort Implementation:** The `merge_sort` function was correctly implemented, incorporating recursive division and merging steps.
# *   **Demonstration of Correctness:** When tested with `sample_list_merge = [64, 25, 12, 22, 11, 78, 33, 90]`, the function correctly sorted it to `[11, 12, 22, 25, 33, 64, 78, 90]`.
# *   **Performance Measurement:** Execution times for `merge_sort` were measured for input sizes ranging from 1,000 to 1,000,000:
#     *   For `n = 1,000`, the execution time was approximately 5.39 ms.
#     *   For `n = 100,000`, it was approximately 495.37 ms.
#     *   For `n = 1,000,000`, the execution time was approximately 4569.11 ms.
# *   **Performance Visualization:** A log-log plot was generated, illustrating the relationship between input size and execution time for `merge_sort`, confirming its performance scaling characteristics.
#
# ### Insights or Next Steps
# *   The observed execution times and their scaling suggest that the implemented `merge_sort` algorithm exhibits the expected O(N log N) time complexity.
# *   Further analysis could involve comparing the performance of `merge_sort` against other sorting algorithms (e.g., Quick Sort, Heap Sort) using the same methodology and plotting their performance curves on the same graph for direct comparison.
